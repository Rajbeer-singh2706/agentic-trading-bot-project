# %%
## AGENTIC AI PROJECT ######

# %% [markdown]
# ## **Challanges**

# %%
### same set of try & exception writing everywhere , how to make it centralized and write in single place so 
## it shuld not be repitivive

## vector dimension based on embedding model as of now its hardcoded

# %%
## Installation ###
'''
 * uv python list 
 * uv python install 3.10
 * uv venv --python 3.10
 * uv init
 * uv add -r requirements.txt
'''
# Out:
# '\n * uv python list \n * uv python install 3.10\n * uv venv --python 3.10\n * uv init\n * uv add -r requirements.txt\n'

# %%
## Problem Statement
## Architecture of Project
## TECH STACK
## DEPLOYMENT

# %%
## Problem Statement

# %%
## TEch Stack

# %% [markdown]
# ## **RUN**

# %%
###

# %% [markdown]
# ## **TO DO in EVERY PROJECT**

# %%
####### TO DO in EVERY PROJECT ###########
## 1. ADd exception & Logger and each Project 
## 2. UNIT Test

# %% [markdown]
# ## **Question**

# %%
# Q) How to catch exception , 
# Q) User message vs Developer Message
# Q) Can we use MCP Server?
# if any eeror come in flipkart , user will not see any techincal error message.
# Q) Metadata in while creating the documents 
# Q) How to decide the dimension?
# Q) Model is slow from UI ? How to achieve better speed ?

# %%
## to fllow the directory : 
## follow this project 
## https://github.com/sunnysavita10/Network_Security

# %%
######### REtriver ==> ###########
'''
  1. data collect, 
  2. Embeddding,
 3. Store the data in VDB(lanceDB OR PineCone)
'''

# %%
## Overview of Project 
## trading data 
'''
  * INPUT ==> LLM (decide) ==> END 
          ==> TOOLS LIST[tavily,polygon,Retriver]
  
'''
# 1 Agent with 3 tools

# %%
#### Data Ingestion ###
'''
 * 
'''

# %%
## pinecone ##
# if we are running in production envriomen , how uuid is generated? are we tracking anywhere

# %%
### Logging ###

# %%
# POLYGON API KEY ==> (polygon.io)

# %%
### Fast API ==> to create endpoint 
## FAST API SERVER 
'''
 * from Streamlit ==> call the endpoint 
 * Fast APi RUN COMMAND : 
'''

# %%
## data
## stock.pdf

# %%
####### DECORATOR 
## Problem : we were writing try & catch everywhere ,
## can we use dectorators so we shuld write only one place

# %%
## check with AI ==> How can we improve the current codebase ?

# %%
## DEvelop UI  ===> JavaAScript/TypeScript

# %% [markdown]
# ## **Qustion**

# %%
## what is a average sensex?

# %%
#   uv pip install -e .
